# %%
from __future__ import (absolute_import, division, print_function,unicode_literals)
import backtrader as bt
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

# %% [markdown]
# ## 数据准备

# %%
#设置数据文件路径
datapath=r'/Users/nilei/Nutstore/Data/EURUSD_D1.csv'

# %%
from dateutil import parser
def getDateTime(s):
    d = parser.parse(s)
    return d
df=pd.read_csv(datapath)
df.index=df['Time (UTC)'].apply(lambda x:getDateTime(x))
old=df.columns[1:]
new=['open','high','low','close','volume']
df=df.rename(columns=dict(zip(old,new)))
df=df.iloc[:,1:]
df['openinterest']=0
df.head()
# Out:
#                open     high      low    close   volume  openinterest
# Time (UTC)
# 2010-01-01  1.43283  1.43356  1.43181  1.43335  76787.4             0
# 2010-01-03  1.43295  1.43359  1.42910  1.43141   6331.3             0
# 2010-01-04  1.43143  1.44556  1.42559  1.44244  80019.4             0
# 2010-01-05  1.44238  1.44834  1.43445  1.43634  79887.1             0
# 2010-01-06  1.43638  1.44342  1.42807  1.44005  80971.8             0

# %%
datapath=r'/Users/nilei/Nutstore/Data/EURUSD_D1.csv'         #macos
dt=pd.read_csv(datapath)
dt.rename(columns={'Time (UTC)':'Date'},inplace=True)
dt.index=pd.to_datetime(dt.Date)
dt.drop(columns='Date',inplace=True)
dt.rename(columns={'Open':'open','High':'high','Low':'low','Close':'close','Volume ':'volume'},inplace=True)
dt.head()
# Out:
#                open     high      low    close   volume
# Date
# 2010-01-01  1.43283  1.43356  1.43181  1.43335  76787.4
# 2010-01-03  1.43295  1.43359  1.42910  1.43141   6331.3
# 2010-01-04  1.43143  1.44556  1.42559  1.44244  80019.4
# 2010-01-05  1.44238  1.44834  1.43445  1.43634  79887.1
# 2010-01-06  1.43638  1.44342  1.42807  1.44005  80971.8

# %%
import datetime as datetime
data = bt.feeds.PandasData(dataname=df,                               
                            fromdate=datetime.datetime(2019, 1, 1),                               
                            todate=datetime.datetime(2020, 1, 1) )

# %% [markdown]
# ## 策略

# %%
class MyStrategy(bt.Strategy):
    def __init__(self):
        # 初始化交易指令、买卖价格和手续费
        self.dataclose=self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None

        #添加移动均线指标
        self.fast_ma = bt.indicators.SimpleMovingAverage(
                      self.datas[0], period=5)
        self.slow_ma = bt.indicators.SimpleMovingAverage(
                      self.datas[0], period=20)
    #记录交易执行情况（可省略，默认不输出结果）
    def notify_order(self, order):
        # 如果order为submitted/accepted,返回空
        if order.status in [order.Submitted, order.Accepted]:
            return
        # 如果order为buy/sell executed,报告价格结果
        if order.status in [order.Completed]: 
            if order.isbuy():
                self.log(f'买入:\n价格:{order.executed.price},\
                成本:{order.executed.value},\
                手续费:{order.executed.comm:.2f}')
                
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:
                self.log(f'卖出:\n价格：{order.executed.price},\
                成本: {-order.executed.value},\
                手续费{order.executed.comm:.2f}')
            
            self.bar_executed = len(self) 
            
        # 如果指令取消/交易失败, 报告结果
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('交易失败')
        self.order = None
    
    #记录交易收益情况（可省略，默认不输出结果）
    def notify_trade(self,trade):
        if not trade.isclosed:
            return
        self.log(f'策略收益：\n毛收益 {trade.pnl:.2f}, 净收益 {trade.pnlcomm:.2f}')
    def next(self):
        
        if self.order: # 检查是否有指令等待执行, 
            return
        #均线下穿，做空
        if self.slow_ma[-2]<self.fast_ma[-2] and self.slow_ma[-1] >= self.fast_ma[-1]:
            if self.position:
                #平多仓
                self.log('平仓:')
                #执行卖出
                self.order = self.sell()
            else:
                #开空仓
                self.log('开空:')
                #执行卖出
                self.order = self.sell()
            
        #均线上穿，做多
        if self.slow_ma[-2]>=self.fast_ma[-2] and self.slow_ma[-1] < self.fast_ma[-1]:
            if self.position:
                #平空仓
                self.log('平仓:')
                #执行买入
                self.order = self.buy()
                    
            else:
                #开多仓
                self.log('开多:')
                #执行买入
                self.order = self.buy()
                
    #交易记录日志（可省略，默认不输出结果）
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print(f'{dt.isoformat()},{txt}')

# %% [markdown]
# ## 回测框架

# %%
def main(startcash,com):
    cerebro = bt.Cerebro()      
    #导入策略参数寻优
    cerebro.addstrategy(MyStrategy)    
    #将数据加载至回测系统
    cerebro.adddata(data)
    #broker设置资金、手续费
    cerebro.broker.setcash(startcash)           
    cerebro.broker.setcommission(commission=com)    
    #设置买入设置，策略，数量
    cerebro.addsizer(bt.sizers.FixedSize,stake=100000)
    print('期初总资金: %.2f' % cerebro.broker.getvalue())    
    cerebro.run()
    portvalue = cerebro.broker.getvalue()
    pnl = portvalue - startcash
    #打印结果
    print(f'总资金：{round(portvalue,2)}')
    print(f'净收益: {round(pnl,2)}')
    cerebro.plot()

# %%
main(100000,0.00001)
# Out:
# 期初总资金: 100000.00
# 2019-01-31,开多:
# 2019-02-01,交易失败
# 2019-02-08,开空:
# 2019-02-10,卖出:
# 价格：1.13186,                成本: 113186.00000000001,                手续费1.13
# 2019-02-26,平仓:
# 2019-02-27,买入:
# 价格:1.13931,                成本:-113186.00000000001,                手续费:1.14
# 2019-02-27,策略收益：
# 毛收益 -745.00, 净收益 -747.27
# 2019-03-08,开空:
# 2019-03-10,卖出:
# 价格：1.12316,                成本: 112316.0,                手续费1.12
# 2019-03-19,平仓:
# 2019-03-20,买入:
# 价格:1.13543,                成本:-112316.0,                手续费:1.14
# 2019-03-20,策略收益：
# 毛收益 -1227.00, 净收益 -1229.26
# 2019-03-28,开空:
# 2019-03-29,卖出:
# 价格：1.12297,                成本: 112297.0,                手续费1.12
# 2019-04-14,平仓:
# 2019-04-15,买入:
# 价格:1.13029,                成本:-112297.0,                手续费:1.13
# 2019-04-15,策略收益：
# 毛收益 -732.00, 净收益 -734.25
# 2019-04-24,开空:
# 2019-04-25,卖出:
# 价格：1.11534,                成本: 111534.0,                手续费1.12
# 2019-05-12,平仓:
# 2019-05-13,买入:
# 价格:1.12358,                成本:-111534.0,                手续费:1.12
# 2019-05-13,策略收益：
# 毛收益 -824.00, 净收益 -826.24
# 2019-05-20,开空:
# 2019-05-21,卖出:
# 价格：1.11673,                成本: 111673.0,                手续费1.12
# 2019-06-05,平仓:
# 2019-06-06,买入:
# 价格:1.12286,                成本:-111673.0,                手续费:1.12
# 2019-06-06,策略收益：
# 毛收益 -613.00, 净收益 -615.24
# 2019-06-19,开空:
# 2019-06-20,卖出:
# 价格：1.1235700000000002,                成本: 112357.00000000001,                手续费1.12
# 2019-06-23,平仓:
# 2019-06-24,买入:
# 价格:1.1385,                成本:-112357.00000000001,                手续费:1.14
# 2019-06-24,策略收益：
# 毛收益 -1493.00, 净收益 -1495.26
# 2019-07-05,开空:
# 2019-07-07,卖出:
# 价格：1.12215,                成本: 112215.0,                手续费1.12
# 2019-08-08,平仓:
# 2019-08-09,买入:
# 价格:1.11861,                成本:-112215.0,                手续费:1.12
# 2019-08-09,策略收益：
# 毛收益 354.00, 净收益 351.76
# 2019-08-18,开空:
# 2019-08-19,卖出:
# 价格：1.1091799999999998,                成本: 110917.99999999999,                手续费1.11
# 2019-09-16,平仓:
# 2019-09-17,买入:
# 价格:1.1003,                成本:-110917.99999999999,                手续费:1.10
# 2019-09-17,策略收益：
# 毛收益 888.00, 净收益 885.79
# 2019-09-24,开空:
# 2019-09-25,卖出:
# 价格：1.10134,                成本: 110134.0,                手续费1.10
# 2019-10-11,平仓:
# 2019-10-13,买入:
# 价格:1.1031600000000001,                成本:-110134.0,                手续费:1.10
# 2019-10-13,策略收益：
# 毛收益 -182.00, 净收益 -184.20
# 2019-11-08,开空:
# 2019-11-10,卖出:
# 价格：1.1023,                成本: 110230.0,                手续费1.10
# 2019-12-04,平仓:
# 2019-12-05,买入:
# 价格:1.10824,                成本:-110230.0,                手续费:1.11
# 2019-12-05,策略收益：
# 毛收益 -594.00, 净收益 -596.21
# 2019-12-24,开空:
# 2019-12-25,卖出:
# 价格：1.10873,                成本: 110873.0,                手续费1.11
# 2019-12-29,平仓:
# 2019-12-30,买入:
# 价格:1.11812,                成本:-110873.0,                手续费:1.12
# 2019-12-30,策略收益：
# 毛收益 -939.00, 净收益 -941.23
# 总资金：93868.38
# 净收益: -6131.62
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## 策略分析

# %%
from collections import OrderedDict
def performance(startcash,com):
    cerebro = bt.Cerebro()      
    #导入策略参数寻优
    cerebro.addstrategy(MyStrategy)    
    #将数据加载至回测系统
    cerebro.adddata(data)
    #broker设置资金、手续费
    cerebro.broker.setcash(startcash)           
    cerebro.broker.setcommission(commission=com)    
    #设置买入设置，策略，数量
    cerebro.addsizer(bt.sizers.FixedSize,stake=100000)
        
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    cerebro.addanalyzer(bt.analyzers.TotalValue, _name='_TotalValue')
    cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='_AnnualReturn')
    cerebro.addanalyzer(bt.analyzers.Calmar, _name='_Calmar')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='_DrawDown')
    cerebro.addanalyzer(bt.analyzers.TimeDrawDown, _name='_TimeDrawDown')
    cerebro.addanalyzer(bt.analyzers.GrossLeverage, _name='_GrossLeverage')
    cerebro.addanalyzer(bt.analyzers.PositionsValue, _name='_PositionsValue')
    cerebro.addanalyzer(bt.analyzers.LogReturnsRolling, _name='_LogReturnsRolling')
    cerebro.addanalyzer(bt.analyzers.PeriodStats, _name='_PeriodStats')
    cerebro.addanalyzer(bt.analyzers.Returns, _name='_Returns')
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='_SharpeRatio')
    cerebro.addanalyzer(bt.analyzers.SharpeRatio_A, _name='_SharpeRatio_A')
    cerebro.addanalyzer(bt.analyzers.SQN, _name='_SQN')
    cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='_TradeAnalyzer')
    cerebro.addanalyzer(bt.analyzers.Transactions, _name='_Transactions')
    cerebro.addanalyzer(bt.analyzers.VWR, _name='_VWR')
    
    results = cerebro.run()
    
    performance_dict=OrderedDict()
    calmar_ratio=list(results[0].analyzers._Calmar.get_analysis().values())[-1]
    drawdown_info=results[0].analyzers._DrawDown.get_analysis()
    average_drawdown_len=drawdown_info['len']
    average_drawdown_rate=drawdown_info['drawdown']
    average_drawdown_money=drawdown_info['moneydown']
    max_drawdown_len=drawdown_info['max']['len']
    max_drawdown_rate=drawdown_info['max']['drawdown']
    max_drawdown_money=drawdown_info['max']['moneydown']
    PeriodStats_info=results[0].analyzers._PeriodStats.get_analysis()
    average_rate=PeriodStats_info['average']
    stddev_rate=PeriodStats_info['stddev']
    positive_year=PeriodStats_info['positive']
    negative_year=PeriodStats_info['negative']
    nochange_year=PeriodStats_info['nochange']
    best_year=PeriodStats_info['best']
    worst_year=PeriodStats_info['worst']
    SQN_info=results[0].analyzers._SQN.get_analysis()
    sqn_ratio=SQN_info['sqn']
    VWR_info=results[0].analyzers._VWR.get_analysis()
    vwr_ratio=VWR_info['vwr']
    sharpe_info=results[0].analyzers._SharpeRatio.get_analysis()
    # sharpe_info=results[0].analyzers._SharpeRatio_A.get_analysis()
    sharpe_ratio=sharpe_info['sharperatio']

    performance_dict['calmar_ratio']=round(calmar_ratio*100,3)
    performance_dict['average_drawdown_len']=average_drawdown_len
    performance_dict['average_drawdown_rate']=round(average_drawdown_rate,2)
    performance_dict['average_drawdown_money']=round(average_drawdown_money,2)
    performance_dict['max_drawdown_len']=max_drawdown_len
    performance_dict['max_drawdown_rate']=round(max_drawdown_rate,2)
    performance_dict['max_drawdown_money']=round(max_drawdown_money,2)
    performance_dict['average_rate']=round(average_rate,2)
    performance_dict['stddev_rate']=round(stddev_rate,2)
    performance_dict['positive_year']=positive_year
    performance_dict['negative_year']=negative_year
    performance_dict['nochange_year']=nochange_year
    performance_dict['best_year']=round(best_year*100,2)
    performance_dict['worst_year']=round(worst_year*100,2)
    performance_dict['sqn_ratio']=round(sqn_ratio,2)
    performance_dict['vwr_ratio']=round(vwr_ratio,2)
    performance_dict['sharpe_info']=round(sharpe_ratio,2)
    performance_dict['omega']=0

    trade_dict_1=OrderedDict()
    trade_dict_2=OrderedDict()
    trade_info=results[0].analyzers._TradeAnalyzer.get_analysis()
    total_trade_num=trade_info['total']['total']
    total_trade_opened=trade_info['total']['open']
    total_trade_closed=trade_info['total']['closed']
    total_trade_len=trade_info['len']['total']
    long_trade_len=trade_info['len']['long']['total']
    short_trade_len=trade_info['len']['short']['total']
    
    longest_win_num=trade_info['streak']['won']['longest']
    longest_lost_num=trade_info['streak']['lost']['longest']
    net_total_pnl=trade_info['pnl']['net']['total']
    net_average_pnl=trade_info['pnl']['net']['average']
    win_num=trade_info['won']['total']
    win_total_pnl=trade_info['won']['pnl']['total']
    win_average_pnl=trade_info['won']['pnl']['average']
    win_max_pnl=trade_info['won']['pnl']['max']
    lost_num=trade_info['lost']['total']
    lost_total_pnl=trade_info['lost']['pnl']['total']
    lost_average_pnl=trade_info['lost']['pnl']['average']
    lost_max_pnl=trade_info['lost']['pnl']['max']
    
    trade_dict_1['total_trade_num']=total_trade_num
    trade_dict_1['total_trade_opened']=total_trade_opened
    trade_dict_1['total_trade_closed']=total_trade_closed
    trade_dict_1['total_trade_len']=total_trade_len
    trade_dict_1['long_trade_len']=long_trade_len
    trade_dict_1['short_trade_len']=short_trade_len
    trade_dict_1['longest_win_num']=longest_win_num
    trade_dict_1['longest_lost_num']=longest_lost_num
    trade_dict_1['net_total_pnl']=net_total_pnl
    trade_dict_1['net_average_pnl']=net_average_pnl
    trade_dict_1['win_num']=win_num
    trade_dict_1['win_total_pnl']=win_total_pnl
    trade_dict_1['win_average_pnl']=win_average_pnl
    trade_dict_1['win_max_pnl']=win_max_pnl
    trade_dict_1['lost_num']=lost_num
    trade_dict_1['lost_total_pnl']=lost_total_pnl
    trade_dict_1['lost_average_pnl']=lost_average_pnl
    trade_dict_1['lost_max_pnl']=lost_max_pnl
    
    long_num=trade_info['long']['total']
    long_win_num=trade_info['long']['won']
    long_lost_num=trade_info['long']['lost']
    long_total_pnl=trade_info['long']['pnl']['total']
    long_average_pnl=trade_info['long']['pnl']['average']
    long_win_total_pnl=trade_info['long']['pnl']['won']['total']
    long_win_max_pnl=trade_info['long']['pnl']['won']['max']
    long_lost_total_pnl=trade_info['long']['pnl']['lost']['total']
    long_lost_max_pnl=trade_info['long']['pnl']['lost']['max']
    
    short_num=trade_info['short']['total']
    short_win_num=trade_info['short']['won']
    short_lost_num=trade_info['short']['lost']
    short_total_pnl=trade_info['short']['pnl']['total']
    short_average_pnl=trade_info['short']['pnl']['average']
    short_win_total_pnl=trade_info['short']['pnl']['won']['total']
    short_win_max_pnl=trade_info['short']['pnl']['won']['max']
    short_lost_total_pnl=trade_info['short']['pnl']['lost']['total']
    short_lost_max_pnl=trade_info['short']['pnl']['lost']['max']
    
    trade_dict_2['long_num']=long_num
    trade_dict_2['long_win_num']=long_win_num
    trade_dict_2['long_lost_num']=long_lost_num
    trade_dict_2['long_total_pnl']=long_total_pnl
    trade_dict_2['long_average_pnl']=long_average_pnl
    trade_dict_2['long_win_total_pnl']=long_win_total_pnl
    trade_dict_2['long_win_max_pnl']=long_win_max_pnl
    trade_dict_2['long_lost_total_pnl']=long_lost_total_pnl
    trade_dict_2['long_lost_max_pnl']=long_lost_max_pnl
    trade_dict_2['short_num']=short_num
    trade_dict_2['short_win_num']=short_win_num
    trade_dict_2['short_lost_num']=short_lost_num
    trade_dict_2['short_total_pnl']=short_total_pnl
    trade_dict_2['short_average_pnl']=short_average_pnl
    trade_dict_2['short_win_total_pnl']=short_win_total_pnl
    trade_dict_2['short_win_max_pnl']=short_win_max_pnl
    trade_dict_2['short_lost_total_pnl']=short_lost_total_pnl
    trade_dict_2['short_lost_max_pnl']=short_lost_max_pnl

    df00=pd.DataFrame(index=range(len(performance_dict)))
    df01=pd.DataFrame([performance_dict]).T
    df01.columns=['绩效指标值']
    df02=pd.DataFrame([trade_dict_1]).T
    df02.columns=['普通交易指标值']
    df03=pd.DataFrame([trade_dict_2]).T
    df03.columns=['多空交易指标值']
    df00['绩效指标']=df01.index
    df00['绩效指标值']=df01.round(4).values
    df00['普通交易指标']=df02.index
    df00['普通交易指标值']=[round(float(i),4) for i in list(df02['普通交易指标值'])]
    df00['多空交易指标']=df03.index
    df00['多空交易指标值']=[round(float(i),4) for i in list(df03['多空交易指标值'])]
    
    # 账户收益率
    df0=df1=pd.DataFrame([results[0].analyzers._TotalValue.get_analysis()]).T
    df0.columns=['total_value']
    
    # 总的杠杆
    df1=pd.DataFrame([results[0].analyzers._GrossLeverage.get_analysis()]).T
    df1.columns=['GrossLeverage']
    

    # 滚动的对数收益率
    df2=pd.DataFrame([results[0].analyzers._LogReturnsRolling.get_analysis()]).T
    df2.columns=['log_return']
    
    # year_rate
    df3=pd.DataFrame([results[0].analyzers._AnnualReturn.get_analysis()]).T
    df3.columns=['year_rate']
    
    # 总的持仓价值
    df4=pd.DataFrame(results[0].analyzers._PositionsValue.get_analysis()).T
    df4['total_position_value']=df4.sum(axis=1)

    pyfoliozer = results[0].analyzers.getbyname('pyfolio')
    returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
    return df00,df0,df1,df2,df3,df4

# %%
k1,k2,k3,k4,k5,k6=performance(100000,0.00001)
# Out:
# 2010-03-04,开多:
# 2010-03-05,交易失败
# 2010-03-22,开空:
# 2010-03-23,卖出:
# 价格：1.35665,                成本: 135665.0,                手续费1.36
# 2010-04-13,平仓:
# 2010-04-14,买入:
# 价格:1.36131,                成本:-135665.0,                手续费:1.36
# 2010-04-14,策略收益：
# 毛收益 -466.00, 净收益 -468.72
# 2010-04-21,开空:
# 2010-04-22,卖出:
# 价格：1.33864,                成本: 133864.0,                手续费1.34
# 2010-06-16,平仓:
# 2010-06-17,买入:
# 价格:1.22983,                成本:-133864.0,                手续费:1.23
# 2010-06-17,策略收益：
# 毛收益 10881.00, 净收益 10878.43
# 2010-08-15,开空:
# 2010-08-16,卖出:
# 价格：1.27541,                成本: 127541.0,                手续费1.28
# 2010-09-05,平仓:
# 2010-09-06,买入:
# 价格:1.2884,                成本:-127541.0,                手续费:1.29
# 2010-09-06,策略收益：
# 毛收益 -1299.00, 净收益 -1301.56
# 2010-09-12,开空:
# 2010-09-13,卖出:
# 价格：1.27585,                成本: 127585.0,                手续费1.28
# 2010-09-14,平仓:
# 2010-09-15,买入:
# 价格:1.2995299999999999,                成本:-127585.0,                手续费:1.30
# 2010-09-15,策略收益：
# 毛收益 -2368.00, 净收益 -2370.58
# 2010-10-25,开空:
# 2010-10-26,卖出:
# 价格：1.39216,                成本: 139216.0,                手续费1.39
# 2010-10-26,平仓:
# 2010-10-27,买入:
# 价格:1.38444,                成本:-139216.0,                手续费:1.38
# 2010-10-27,策略收益：
# 毛收益 772.00, 净收益 769.22
# 2010-10-28,开空:
# 2010-10-29,卖出:
# 价格：1.39424,                成本: 139424.0,                手续费1.39
# 2010-11-03,平仓:
# 2010-11-04,买入:
# 价格:1.41246,                成本:-139424.0,                手续费:1.41
# 2010-11-04,策略收益：
# 毛收益 -1822.00, 净收益 -1824.81
# 2010-11-11,开空:
# 2010-11-12,卖出:
# 价格：1.36198,                成本: 136198.0,                手续费1.36
# 2010-12-15,平仓:
# 2010-12-16,买入:
# 价格:1.32245,                成本:-136198.0,                手续费:1.32
# 2010-12-16,策略收益：
# 毛收益 3953.00, 净收益 3950.32
# 2010-12-20,开空:
# 2010-12-21,卖出:
# 价格：1.31166,                成本: 131166.0,                手续费1.31
# 2011-01-02,平仓:
# 2011-01-03,买入:
# 价格:1.3356,                成本:-131166.0,                手续费:1.34
# 2011-01-03,策略收益：
# 毛收益 -2394.00, 净收益 -2396.65
# 2011-01-09,开空:
# 2011-01-10,卖出:
# 价格：1.2894700000000001,                成本: 128947.00000000001,                手续费1.29
# 2011-01-17,平仓:
# 2011-01-18,买入:
# 价格:1.32809,                成本:-128947.00000000001,                手续费:1.33
# 2011-01-18,策略收益：
# 毛收益 -3862.00, 净收益 -3864.62
# 2011-02-09,开空:
# 2011-02-10,卖出:
# 价格：1.37189,                成本: 137189.0,                手续费1.37
# 2011-02-22,平仓:
# 2011-02-23,买入:
# 价格:1.36726,                成本:-137189.0,                手续费:1.37
# 2011-02-23,策略收益：
# 毛收益 463.00, 净收益 460.26
# 2011-05-09,开空:
# 2011-05-10,卖出:
# 价格：1.43678,                成本: 143678.0,                手续费1.44
# 2011-05-31,平仓:
# 2011-06-01,买入:
# 价格:1.4424,                成本:-143678.0,                手续费:1.44
# 2011-06-01,策略收益：
# 毛收益 -562.00, 净收益 -564.88
# 2011-06-16,开空:
# 2011-06-17,卖出:
# 价格：1.4201,                成本: 142010.0,                手续费1.42
# 2011-07-01,平仓:
# 2011-07-03,买入:
# 价格:1.4521,                成本:-142010.0,                手续费:1.45
# 2011-07-03,策略收益：
# 毛收益 -3200.00, 净收益 -3202.87
# 2011-07-11,开空:
# 2011-07-12,卖出:
# 价格：1.40381,                成本: 140381.0,                手续费1.40
# 2011-07-25,平仓:
# 2011-07-26,买入:
# 价格:1.4373,                成本:-140381.0,                手续费:1.44
# 2011-07-26,策略收益：
# 毛收益 -3349.00, 净收益 -3351.84
# 2011-08-05,开空:
# 2011-08-07,卖出:
# 价格：1.4276,                成本: 142760.0,                手续费1.43
# 2011-08-17,平仓:
# 2011-08-18,买入:
# 价格:1.44277,                成本:-142760.0,                手续费:1.44
# 2011-08-18,策略收益：
# 毛收益 -1517.00, 净收益 -1519.87
# 2011-09-04,开空:
# 2011-09-05,卖出:
# 价格：1.4148,                成本: 141480.0,                手续费1.41
# 2011-10-12,平仓:
# 2011-10-13,买入:
# 价格:1.37775,                成本:-141480.0,                手续费:1.38
# 2011-10-13,策略收益：
# 毛收益 3705.00, 净收益 3702.21
# 2011-11-04,开空:
# 2011-11-06,卖出:
# 价格：1.37947,                成本: 137947.0,                手续费1.38
# 2012-01-22,平仓:
# 2012-01-23,买入:
# 价格:1.28865,                成本:-137947.0,                手续费:1.29
# 2012-01-23,策略收益：
# 毛收益 9082.00, 净收益 9079.33
# 2012-02-16,开空:
# 2012-02-17,卖出:
# 价格：1.31269,                成本: 131269.0,                手续费1.31
# 2012-02-22,平仓:
# 2012-02-23,买入:
# 价格:1.3255,                成本:-131269.0,                手续费:1.33
# 2012-02-23,策略收益：
# 毛收益 -1281.00, 净收益 -1283.64
# 2012-03-06,开空:
# 2012-03-07,卖出:
# 价格：1.31194,                成本: 131194.0,                手续费1.31
# 2012-03-22,平仓:
# 2012-03-23,买入:
# 价格:1.32044,                成本:-131194.0,                手续费:1.32
# 2012-03-23,策略收益：
# 毛收益 -850.00, 净收益 -852.63
# 2012-04-06,开空:
# 2012-04-08,卖出:
# 价格：1.30946,                成本: 130946.0,                手续费1.31
# 2012-04-23,平仓:
# 2012-04-24,买入:
# 价格:1.31487,                成本:-130946.0,                手续费:1.31
# 2012-04-24,策略收益：
# 毛收益 -541.00, 净收益 -543.62
# 2012-05-07,开空:
# 2012-05-08,卖出:
# 价格：1.30587,                成本: 130587.00000000001,                手续费1.31
# 2012-06-12,平仓:
# 2012-06-13,买入:
# 价格:1.25,                成本:-130587.00000000001,                手续费:1.25
# 2012-06-13,策略收益：
# 毛收益 5587.00, 净收益 5584.44
# 2012-06-27,开空:
# 2012-06-28,卖出:
# 价格：1.24696,                成本: 124696.0,                手续费1.25
# 2012-07-04,平仓:
# 2012-07-05,买入:
# 价格:1.25152,                成本:-124696.0,                手续费:1.25
# 2012-07-05,策略收益：
# 毛收益 -456.00, 净收益 -458.50
# 2012-07-06,开空:
# 2012-07-08,卖出:
# 价格：1.22351,                成本: 122351.00000000001,                手续费1.22
# 2012-07-31,平仓:
# 2012-08-01,买入:
# 价格:1.22916,                成本:-122351.00000000001,                手续费:1.23
# 2012-08-01,策略收益：
# 毛收益 -565.00, 净收益 -567.45
# 2012-09-30,开空:
# 2012-10-01,卖出:
# 价格：1.28077,                成本: 128077.0,                手续费1.28
# 2012-10-08,平仓:
# 2012-10-09,买入:
# 价格:1.29749,                成本:-128077.0,                手续费:1.30
# 2012-10-09,策略收益：
# 毛收益 -1672.00, 净收益 -1674.58
# 2012-10-12,开空:
# 2012-10-14,卖出:
# 价格：1.29501,                成本: 129501.0,                手续费1.30
# 2012-10-16,平仓:
# 2012-10-17,买入:
# 价格:1.31055,                成本:-129501.0,                手续费:1.31
# 2012-10-17,策略收益：
# 毛收益 -1554.00, 净收益 -1556.61
# 2012-10-28,开空:
# 2012-10-29,卖出:
# 价格：1.29216,                成本: 129216.0,                手续费1.29
# 2012-11-23,平仓:
# 2012-11-25,买入:
# 价格:1.29691,                成本:-129216.0,                手续费:1.30
# 2012-11-25,策略收益：
# 毛收益 -475.00, 净收益 -477.59
# 2012-12-12,开空:
# 2012-12-13,卖出:
# 价格：1.30653,                成本: 130653.0,                手续费1.31
# 2012-12-13,平仓:
# 2012-12-14,买入:
# 价格:1.30767,                成本:-130653.0,                手续费:1.31
# 2012-12-14,策略收益：
# 毛收益 -114.00, 净收益 -116.61
# 2013-01-04,开空:
# 2013-01-06,卖出:
# 价格：1.30745,                成本: 130745.0,                手续费1.31
# 2013-01-13,平仓:
# 2013-01-14,买入:
# 价格:1.33579,                成本:-130745.0,                手续费:1.34
# 2013-01-14,策略收益：
# 毛收益 -2834.00, 净收益 -2836.64
# 2013-02-11,开空:
# 2013-02-12,卖出:
# 价格：1.34016,                成本: 134016.0,                手续费1.34
# 2013-04-08,平仓:
# 2013-04-09,买入:
# 价格:1.30293,                成本:-134016.0,                手续费:1.30
# 2013-04-09,策略收益：
# 毛收益 3723.00, 净收益 3720.36
# 2013-04-26,开空:
# 2013-04-28,卖出:
# 价格：1.30504,                成本: 130504.0,                手续费1.31
# 2013-05-01,平仓:
# 2013-05-02,买入:
# 价格:1.3179299999999996,                成本:-130504.0,                手续费:1.32
# 2013-05-02,策略收益：
# 毛收益 -1289.00, 净收益 -1291.62
# 2013-05-12,开空:
# 2013-05-13,卖出:
# 价格：1.2967,                成本: 129670.0,                手续费1.30
# 2013-05-31,平仓:
# 2013-06-02,买入:
# 价格:1.2993299999999999,                成本:-129670.0,                手续费:1.30
# 2013-06-02,策略收益：
# 毛收益 -263.00, 净收益 -265.60
# 2013-06-25,开空:
# 2013-06-26,卖出:
# 价格：1.30755,                成本: 130755.0,                手续费1.31
# 2013-07-15,平仓:
# 2013-07-16,买入:
# 价格:1.3058,                成本:-130755.0,                手续费:1.31
# 2013-07-16,策略收益：
# 毛收益 175.00, 净收益 172.39
# 2013-09-01,开空:
# 2013-09-02,卖出:
# 价格：1.32067,                成本: 132067.0,                手续费1.32
# 2013-09-15,平仓:
# 2013-09-16,买入:
# 价格:1.33585,                成本:-132067.0,                手续费:1.34
# 2013-09-16,策略收益：
# 毛收益 -1518.00, 净收益 -1520.66
# 2013-10-17,开空:
# 2013-10-18,卖出:
# 价格：1.36683,                成本: 136683.0,                手续费1.37
# 2013-10-18,平仓:
# 2013-10-20,买入:
# 价格:1.3684,                成本:-136683.0,                手续费:1.37
# 2013-10-20,策略收益：
# 毛收益 -157.00, 净收益 -159.74
# 2013-11-04,开空:
# 2013-11-05,卖出:
# 价格：1.35152,                成本: 135152.0,                手续费1.35
# 2013-11-22,平仓:
# 2013-11-24,买入:
# 价格:1.35481,                成本:-135152.0,                手续费:1.35
# 2013-11-24,策略收益：
# 毛收益 -329.00, 净收益 -331.71
# 2013-12-24,开空:
# 2013-12-25,卖出:
# 价格：1.36725,                成本: 136725.0,                手续费1.37
# 2013-12-31,平仓:
# 2014-01-01,买入:
# 价格:1.37553,                成本:-136725.0,                手续费:1.38
# 2014-01-01,策略收益：
# 毛收益 -828.00, 净收益 -830.74
# 2014-01-06,开空:
# 2014-01-07,卖出:
# 价格：1.36297,                成本: 136297.0,                手续费1.36
# 2014-01-27,平仓:
# 2014-01-28,买入:
# 价格:1.36741,                成本:-136297.0,                手续费:1.37
# 2014-01-28,策略收益：
# 毛收益 -444.00, 净收益 -446.73
# 2014-02-02,开空:
# 2014-02-03,卖出:
# 价格：1.34873,                成本: 134873.0,                手续费1.35
# 2014-02-11,平仓:
# 2014-02-12,买入:
# 价格:1.36366,                成本:-134873.0,                手续费:1.36
# 2014-02-12,策略收益：
# 毛收益 -1493.00, 净收益 -1495.71
# 2014-03-24,开空:
# 2014-03-25,卖出:
# 价格：1.38364,                成本: 138364.0,                手续费1.38
# 2014-04-11,平仓:
# 2014-04-13,买入:
# 价格:1.3843299999999996,                成本:-138364.0,                手续费:1.38
# 2014-04-13,策略收益：
# 毛收益 -69.00, 净收益 -71.77
# 2014-05-13,开空:
# 2014-05-14,卖出:
# 价格：1.37077,                成本: 137077.0,                手续费1.37
# 2014-06-24,平仓:
# 2014-06-25,买入:
# 价格:1.36059,                成本:-137077.0,                手续费:1.36
# 2014-06-25,策略收益：
# 毛收益 1018.00, 净收益 1015.27
# 2014-07-08,开空:
# 2014-07-09,卖出:
# 价格：1.36166,                成本: 136166.0,                手续费1.36
# 2014-10-16,平仓:
# 2014-10-17,买入:
# 价格:1.28043,                成本:-136166.0,                手续费:1.28
# 2014-10-17,策略收益：
# 毛收益 8123.00, 净收益 8120.36
# 2014-10-27,开空:
# 2014-10-28,卖出:
# 价格：1.2702200000000001,                成本: 127022.00000000001,                手续费1.27
# 2014-11-20,平仓:
# 2014-11-21,买入:
# 价格:1.2543,                成本:-127022.00000000001,                手续费:1.25
# 2014-11-21,策略收益：
# 毛收益 1592.00, 净收益 1589.48
# 2014-11-24,开空:
# 2014-11-25,卖出:
# 价格：1.24339,                成本: 124339.0,                手续费1.24
# 2014-11-30,平仓:
# 2014-12-01,买入:
# 价格:1.24368,                成本:-124339.0,                手续费:1.24
# 2014-12-01,策略收益：
# 毛收益 -29.00, 净收益 -31.49
# 2014-12-01,开空:
# 2014-12-02,卖出:
# 价格：1.24699,                成本: 124699.0,                手续费1.25
# 2014-12-15,平仓:
# 2014-12-16,买入:
# 价格:1.24401,                成本:-124699.0,                手续费:1.24
# 2014-12-16,策略收益：
# 毛收益 298.00, 净收益 295.51
# 2014-12-21,开空:
# 2014-12-22,卖出:
# 价格：1.22245,                成本: 122245.0,                手续费1.22
# 2015-02-15,平仓:
# 2015-02-16,买入:
# 价格:1.13975,                成本:-122245.0,                手续费:1.14
# 2015-02-16,策略收益：
# 毛收益 8270.00, 净收益 8267.64
# 2015-02-25,开空:
# 2015-02-26,卖出:
# 价格：1.13637,                成本: 113637.00000000001,                手续费1.14
# 2015-03-24,平仓:
# 2015-03-25,买入:
# 价格:1.09045,                成本:-113637.00000000001,                手续费:1.09
# 2015-03-25,策略收益：
# 毛收益 4592.00, 净收益 4589.77
# 2015-04-10,开空:
# 2015-04-12,卖出:
# 价格：1.05853,                成本: 105853.0,                手续费1.06
# 2015-04-22,平仓:
# 2015-04-23,买入:
# 价格:1.07247,                成本:-105853.0,                手续费:1.07
# 2015-04-23,策略收益：
# 毛收益 -1394.00, 净收益 -1396.13
# 2015-05-22,开空:
# 2015-05-24,卖出:
# 价格：1.10016,                成本: 110016.0,                手续费1.10
# 2015-06-07,平仓:
# 2015-06-08,买入:
# 价格:1.1102299999999998,                成本:-110016.0,                手续费:1.11
# 2015-06-08,策略收益：
# 毛收益 -1007.00, 净收益 -1009.21
# 2015-06-26,开空:
# 2015-06-28,卖出:
# 价格：1.10049,                成本: 110049.0,                手续费1.10
# 2015-07-28,平仓:
# 2015-07-29,买入:
# 价格:1.10651,                成本:-110049.0,                手续费:1.11
# 2015-07-29,策略收益：
# 毛收益 -602.00, 净收益 -604.21
# 2015-08-05,开空:
# 2015-08-06,卖出:
# 价格：1.09029,                成本: 109029.0,                手续费1.09
# 2015-08-12,平仓:
# 2015-08-13,买入:
# 价格:1.1154700000000002,                成本:-109029.0,                手续费:1.12
# 2015-08-13,策略收益：
# 毛收益 -2518.00, 净收益 -2520.21
# 2015-09-03,开空:
# 2015-09-04,卖出:
# 价格：1.11239,                成本: 111239.0,                手续费1.11
# 2015-09-15,平仓:
# 2015-09-16,买入:
# 价格:1.12701,                成本:-111239.0,                手续费:1.13
# 2015-09-16,策略收益：
# 毛收益 -1462.00, 净收益 -1464.24
# 2015-09-24,开空:
# 2015-09-25,卖出:
# 价格：1.11799,                成本: 111799.0,                手续费1.12
# 2015-10-09,平仓:
# 2015-10-11,买入:
# 价格:1.1360299999999999,                成本:-111799.0,                手续费:1.14
# 2015-10-11,策略收益：
# 毛收益 -1804.00, 净收益 -1806.25
# 2015-10-23,开空:
# 2015-10-25,卖出:
# 价格：1.1002,                成本: 110020.0,                手续费1.10
# 2015-12-06,平仓:
# 2015-12-07,买入:
# 价格:1.0881,                成本:-110020.0,                手续费:1.09
# 2015-12-07,策略收益：
# 毛收益 1210.00, 净收益 1207.81
# 2016-01-03,开空:
# 2016-01-04,卖出:
# 价格：1.08515,                成本: 108515.0,                手续费1.09
# 2016-01-13,平仓:
# 2016-01-14,买入:
# 价格:1.08854,                成本:-108515.0,                手续费:1.09
# 2016-01-14,策略收益：
# 毛收益 -339.00, 净收益 -341.17
# 2016-01-14,开空:
# 2016-01-15,卖出:
# 价格：1.0857,                成本: 108570.00000000001,                手续费1.09
# 2016-01-19,平仓:
# 2016-01-20,买入:
# 价格:1.0910600000000001,                成本:-108570.00000000001,                手续费:1.09
# 2016-01-20,策略收益：
# 毛收益 -536.00, 净收益 -538.18
# 2016-01-24,开空:
# 2016-01-25,卖出:
# 价格：1.0797,                成本: 107970.00000000001,                手续费1.08
# 2016-02-02,平仓:
# 2016-02-03,买入:
# 价格:1.0918700000000001,                成本:-107970.00000000001,                手续费:1.09
# 2016-02-03,策略收益：
# 毛收益 -1217.00, 净收益 -1219.17
# 2016-02-23,开空:
# 2016-02-24,卖出:
# 价格：1.10232,                成本: 110232.0,                手续费1.10
# 2016-03-11,平仓:
# 2016-03-13,买入:
# 价格:1.11355,                成本:-110232.0,                手续费:1.11
# 2016-03-13,策略收益：
# 毛收益 -1123.00, 净收益 -1125.22
# 2016-04-18,开空:
# 2016-04-19,卖出:
# 价格：1.13078,                成本: 113077.99999999999,                手续费1.13
# 2016-05-01,平仓:
# 2016-05-02,买入:
# 价格:1.14608,                成本:-113077.99999999999,                手续费:1.15
# 2016-05-02,策略收益：
# 毛收益 -1530.00, 净收益 -1532.28
# 2016-05-15,开空:
# 2016-05-16,卖出:
# 价格：1.13173,                成本: 113172.99999999999,                手续费1.13
# 2016-06-06,平仓:
# 2016-06-07,买入:
# 价格:1.13628,                成本:-113172.99999999999,                手续费:1.14
# 2016-06-07,策略收益：
# 毛收益 -455.00, 净收益 -457.27
# 2016-06-26,开空:
# 2016-06-27,卖出:
# 价格：1.10395,                成本: 110395.0,                手续费1.10
# 2016-07-31,平仓:
# 2016-08-01,买入:
# 价格:1.1167200000000002,                成本:-110395.0,                手续费:1.12
# 2016-08-01,策略收益：
# 毛收益 -1277.00, 净收益 -1279.22
# 2016-08-31,开空:
# 2016-09-01,卖出:
# 价格：1.11564,                成本: 111564.0,                手续费1.12
# 2016-09-12,平仓:
# 2016-09-13,买入:
# 价格:1.12404,                成本:-111564.0,                手续费:1.12
# 2016-09-13,策略收益：
# 毛收益 -840.00, 净收益 -842.24
# 2016-09-20,开空:
# 2016-09-21,卖出:
# 价格：1.1153,                成本: 111530.0,                手续费1.12
# 2016-09-27,平仓:
# 2016-09-28,买入:
# 价格:1.1217,                成本:-111530.0,                手续费:1.12
# 2016-09-28,策略收益：
# 毛收益 -640.00, 净收益 -642.24
# 2016-10-07,开空:
# 2016-10-09,卖出:
# 价格：1.11815,                成本: 111815.0,                手续费1.12
# 2016-11-02,平仓:
# 2016-11-03,买入:
# 价格:1.1094,                成本:-111815.0,                手续费:1.11
# 2016-11-03,策略收益：
# 毛收益 875.00, 净收益 872.77
# 2016-11-13,开空:
# 2016-11-14,卖出:
# 价格：1.08226,                成本: 108226.0,                手续费1.08
# 2016-12-06,平仓:
# 2016-12-07,买入:
# 价格:1.07185,                成本:-108226.0,                手续费:1.07
# 2016-12-07,策略收益：
# 毛收益 1041.00, 净收益 1038.85
# 2016-12-14,开空:
# 2016-12-15,卖出:
# 价格：1.0512,                成本: 105119.99999999999,                手续费1.05
# 2017-01-02,平仓:
# 2017-01-03,买入:
# 价格:1.04575,                成本:-105119.99999999999,                手续费:1.05
# 2017-01-03,策略收益：
# 毛收益 545.00, 净收益 542.90
# 2017-02-10,开空:
# 2017-02-12,卖出:
# 价格：1.06285,                成本: 106285.0,                手续费1.06
# 2017-03-09,平仓:
# 2017-03-10,买入:
# 价格:1.0579399999999999,                成本:-106285.0,                手续费:1.06
# 2017-03-10,策略收益：
# 毛收益 491.00, 净收益 488.88
# 2017-03-10,开空:
# 2017-03-12,卖出:
# 价格：1.0674700000000001,                成本: 106747.00000000001,                手续费1.07
# 2017-03-12,平仓:
# 2017-03-13,买入:
# 价格:1.06894,                成本:-106747.00000000001,                手续费:1.07
# 2017-03-13,策略收益：
# 毛收益 -147.00, 净收益 -149.14
# 2017-04-03,开空:
# 2017-04-04,卖出:
# 价格：1.06695,                成本: 106695.0,                手续费1.07
# 2017-04-20,平仓:
# 2017-04-21,买入:
# 价格:1.0714,                成本:-106695.0,                手续费:1.07
# 2017-04-21,策略收益：
# 毛收益 -445.00, 净收益 -447.14
# 2017-05-15,开空:
# 2017-05-16,卖出:
# 价格：1.09798,                成本: 109798.0,                手续费1.10
# 2017-05-17,平仓:
# 2017-05-18,买入:
# 价格:1.11543,                成本:-109798.0,                手续费:1.12
# 2017-05-18,策略收益：
# 毛收益 -1745.00, 净收益 -1747.21
# 2017-06-13,开空:
# 2017-06-14,卖出:
# 价格：1.12091,                成本: 112091.00000000001,                手续费1.12
# 2017-06-28,平仓:
# 2017-06-29,买入:
# 价格:1.1378,                成本:-112091.00000000001,                手续费:1.14
# 2017-06-29,策略收益：
# 毛收益 -1689.00, 净收益 -1691.26
# 2017-08-18,开空:
# 2017-08-20,卖出:
# 价格：1.1757799999999998,                成本: 117577.99999999999,                手续费1.18
# 2017-08-25,平仓:
# 2017-08-27,买入:
# 价格:1.19431,                成本:-117577.99999999999,                手续费:1.19
# 2017-08-27,策略收益：
# 毛收益 -1853.00, 净收益 -1855.37
# 2017-09-18,开空:
# 2017-09-19,卖出:
# 价格：1.1959799999999998,                成本: 119597.99999999999,                手续费1.20
# 2017-09-20,平仓:
# 2017-09-21,买入:
# 价格:1.1874200000000001,                成本:-119597.99999999999,                手续费:1.19
# 2017-09-21,策略收益：
# 毛收益 856.00, 净收益 853.62
# 2017-09-25,开空:
# 2017-09-26,卖出:
# 价格：1.18556,                成本: 118556.0,                手续费1.19
# 2017-10-15,平仓:
# 2017-10-16,买入:
# 价格:1.18147,                成本:-118556.0,                手续费:1.18
# 2017-10-16,策略收益：
# 毛收益 409.00, 净收益 406.63
# 2017-10-26,开空:
# 2017-10-27,卖出:
# 价格：1.16377,                成本: 116377.0,                手续费1.16
# 2017-11-15,平仓:
# 2017-11-16,买入:
# 价格:1.17826,                成本:-116377.0,                手续费:1.18
# 2017-11-16,策略收益：
# 毛收益 -1449.00, 净收益 -1451.34
# 2017-12-08,开空:
# 2017-12-10,卖出:
# 价格：1.17651,                成本: 117651.0,                手续费1.18
# 2017-12-22,平仓:
# 2017-12-24,买入:
# 价格:1.1844,                成本:-117651.0,                手续费:1.18
# 2017-12-24,策略收益：
# 毛收益 -789.00, 净收益 -791.36
# 2018-02-09,开空:
# 2018-02-11,卖出:
# 价格：1.2248299999999999,                成本: 122482.99999999999,                手续费1.22
# 2018-02-18,平仓:
# 2018-02-19,买入:
# 价格:1.24117,                成本:-122482.99999999999,                手续费:1.24
# 2018-02-19,策略收益：
# 毛收益 -1634.00, 净收益 -1636.47
# 2018-02-22,开空:
# 2018-02-23,卖出:
# 价格：1.23256,                成本: 123256.00000000001,                手续费1.23
# 2018-03-08,平仓:
# 2018-03-09,买入:
# 价格:1.2307,                成本:-123256.00000000001,                手续费:1.23
# 2018-03-09,策略收益：
# 毛收益 186.00, 净收益 183.54
# 2018-03-21,开空:
# 2018-03-22,卖出:
# 价格：1.23464,                成本: 123464.0,                手续费1.23
# 2018-03-27,平仓:
# 2018-03-28,买入:
# 价格:1.24086,                成本:-123464.0,                手续费:1.24
# 2018-03-28,策略收益：
# 毛收益 -622.00, 净收益 -624.48
# 2018-04-02,开空:
# 2018-04-03,卖出:
# 价格：1.2293100000000001,                成本: 122931.00000000001,                手续费1.23
# 2018-04-13,平仓:
# 2018-04-15,买入:
# 价格:1.23278,                成本:-122931.00000000001,                手续费:1.23
# 2018-04-15,策略收益：
# 毛收益 -347.00, 净收益 -349.46
# 2018-04-24,开空:
# 2018-04-25,卖出:
# 价格：1.2237200000000001,                成本: 122372.00000000001,                手续费1.22
# 2018-06-08,平仓:
# 2018-06-10,买入:
# 价格:1.17736,                成本:-122372.00000000001,                手续费:1.18
# 2018-06-10,策略收益：
# 毛收益 4636.00, 净收益 4633.60
# 2018-06-18,开空:
# 2018-06-19,卖出:
# 价格：1.16297,                成本: 116297.0,                手续费1.16
# 2018-07-05,平仓:
# 2018-07-06,买入:
# 价格:1.16919,                成本:-116297.0,                手续费:1.17
# 2018-07-06,策略收益：
# 毛收益 -622.00, 净收益 -624.33
# 2018-07-19,开空:
# 2018-07-20,卖出:
# 价格：1.16547,                成本: 116547.0,                手续费1.17
# 2018-07-25,平仓:
# 2018-07-26,买入:
# 价格:1.17379,                成本:-116547.0,                手续费:1.17
# 2018-07-26,策略收益：
# 毛收益 -832.00, 净收益 -834.34
# 2018-07-29,开空:
# 2018-07-30,卖出:
# 价格：1.16591,                成本: 116591.0,                手续费1.17
# 2018-08-24,平仓:
# 2018-08-26,买入:
# 价格:1.16141,                成本:-116591.0,                手续费:1.16
# 2018-08-26,策略收益：
# 毛收益 450.00, 净收益 447.67
# 2018-09-10,开空:
# 2018-09-11,卖出:
# 价格：1.15935,                成本: 115935.00000000001,                手续费1.16
# 2018-09-16,平仓:
# 2018-09-17,买入:
# 价格:1.16234,                成本:-115935.00000000001,                手续费:1.16
# 2018-09-17,策略收益：
# 毛收益 -299.00, 净收益 -301.32
# 2018-10-02,开空:
# 2018-10-03,卖出:
# 价格：1.15503,                成本: 115503.0,                手续费1.16
# 2018-11-20,平仓:
# 2018-11-21,买入:
# 价格:1.1372,                成本:-115503.0,                手续费:1.14
# 2018-11-21,策略收益：
# 毛收益 1783.00, 净收益 1780.71
# 2018-11-26,开空:
# 2018-11-27,卖出:
# 价格：1.13331,                成本: 113331.0,                手续费1.13
# 2018-12-04,平仓:
# 2018-12-05,买入:
# 价格:1.13425,                成本:-113331.0,                手续费:1.13
# 2018-12-05,策略收益：
# 毛收益 -94.00, 净收益 -96.27
# 2018-12-05,开空:
# 2018-12-06,卖出:
# 价格：1.13487,                成本: 113487.0,                手续费1.13
# 2018-12-10,平仓:
# 2018-12-11,买入:
# 价格:1.1355899999999999,                成本:-113487.0,                手续费:1.14
# 2018-12-11,策略收益：
# 毛收益 -72.00, 净收益 -74.27
# 2018-12-16,开空:
# 2018-12-17,卖出:
# 价格：1.1304299999999998,                成本: 113042.99999999999,                手续费1.13
# 2018-12-21,平仓:
# 2018-12-23,买入:
# 价格:1.1369200000000002,                成本:-113042.99999999999,                手续费:1.14
# 2018-12-23,策略收益：
# 毛收益 -649.00, 净收益 -651.27
# 2019-01-08,开空:
# 2019-01-09,卖出:
# 价格：1.14573,                成本: 114572.99999999999,                手续费1.15
# 2019-01-09,平仓:
# 2019-01-10,买入:
# 价格:1.15541,                成本:-114572.99999999999,                手续费:1.16
# 2019-01-10,策略收益：
# 毛收益 -968.00, 净收益 -970.30
# 2019-01-18,开空:
# 2019-01-20,卖出:
# 价格：1.1360299999999999,                成本: 113602.99999999999,                手续费1.14
# 2019-01-31,平仓:
# 2019-02-01,买入:
# 价格:1.1448200000000002,                成本:-113602.99999999999,                手续费:1.14
# 2019-02-01,策略收益：
# 毛收益 -879.00, 净收益 -881.28
# 2019-02-08,开空:
# 2019-02-10,卖出:
# 价格：1.13186,                成本: 113186.00000000001,                手续费1.13
# 2019-02-26,平仓:
# 2019-02-27,买入:
# 价格:1.13931,                成本:-113186.00000000001,                手续费:1.14
# 2019-02-27,策略收益：
# 毛收益 -745.00, 净收益 -747.27
# 2019-03-08,开空:
# 2019-03-10,卖出:
# 价格：1.12316,                成本: 112316.0,                手续费1.12
# 2019-03-19,平仓:
# 2019-03-20,买入:
# 价格:1.13543,                成本:-112316.0,                手续费:1.14
# 2019-03-20,策略收益：
# 毛收益 -1227.00, 净收益 -1229.26
# 2019-03-28,开空:
# 2019-03-29,卖出:
# 价格：1.12297,                成本: 112297.0,                手续费1.12
# 2019-04-14,平仓:
# 2019-04-15,买入:
# 价格:1.13029,                成本:-112297.0,                手续费:1.13
# 2019-04-15,策略收益：
# 毛收益 -732.00, 净收益 -734.25
# 2019-04-24,开空:
# 2019-04-25,卖出:
# 价格：1.11534,                成本: 111534.0,                手续费1.12
# 2019-05-12,平仓:
# 2019-05-13,买入:
# 价格:1.12358,                成本:-111534.0,                手续费:1.12
# 2019-05-13,策略收益：
# 毛收益 -824.00, 净收益 -826.24
# 2019-05-20,开空:
# 2019-05-21,卖出:
# 价格：1.11673,                成本: 111673.0,                手续费1.12
# 2019-06-05,平仓:
# 2019-06-06,买入:
# 价格:1.12286,                成本:-111673.0,                手续费:1.12
# 2019-06-06,策略收益：
# 毛收益 -613.00, 净收益 -615.24
# 2019-06-19,开空:
# 2019-06-20,卖出:
# 价格：1.1235700000000002,                成本: 112357.00000000001,                手续费1.12
# 2019-06-23,平仓:
# 2019-06-24,买入:
# 价格:1.1385,                成本:-112357.00000000001,                手续费:1.14
# 2019-06-24,策略收益：
# 毛收益 -1493.00, 净收益 -1495.26
# 2019-07-05,开空:
# 2019-07-07,卖出:
# 价格：1.12215,                成本: 112215.0,                手续费1.12
# 2019-08-08,平仓:
# 2019-08-09,买入:
# 价格:1.11861,                成本:-112215.0,                手续费:1.12
# 2019-08-09,策略收益：
# 毛收益 354.00, 净收益 351.76
# 2019-08-18,开空:
# 2019-08-19,卖出:
# 价格：1.1091799999999998,                成本: 110917.99999999999,                手续费1.11
# 2019-09-16,平仓:
# 2019-09-17,买入:
# 价格:1.1003,                成本:-110917.99999999999,                手续费:1.10
# 2019-09-17,策略收益：
# 毛收益 888.00, 净收益 885.79
# 2019-09-24,开空:
# 2019-09-25,卖出:
# 价格：1.10134,                成本: 110134.0,                手续费1.10
# 2019-10-11,平仓:
# 2019-10-13,买入:
# 价格:1.1031600000000001,                成本:-110134.0,                手续费:1.10
# 2019-10-13,策略收益：
# 毛收益 -182.00, 净收益 -184.20
# 2019-11-08,开空:
# 2019-11-10,卖出:
# 价格：1.1023,                成本: 110230.0,                手续费1.10
# 2019-12-04,平仓:
# 2019-12-05,买入:
# 价格:1.10824,                成本:-110230.0,                手续费:1.11
# 2019-12-05,策略收益：
# 毛收益 -594.00, 净收益 -596.21
# 2019-12-24,开空:
# 2019-12-25,卖出:
# 价格：1.10873,                成本: 110873.0,                手续费1.11
# 2019-12-29,平仓:
# 2019-12-30,买入:
# 价格:1.11812,                成本:-110873.0,                手续费:1.12
# 2019-12-30,策略收益：
# 毛收益 -939.00, 净收益 -941.23

# %%
k1
# Out:
#                       绩效指标      绩效指标值              普通交易指标     普通交易指标值  \
# 0             calmar_ratio     -0.017     total_trade_num    100.0000
# 1     average_drawdown_len   1501.000  total_trade_opened      0.0000
# 2    average_drawdown_rate     23.180  total_trade_closed    100.0000
# 3   average_drawdown_money  29837.560     total_trade_len   1581.0000
# 4         max_drawdown_len   1501.000      long_trade_len      0.0000
# 5        max_drawdown_rate     23.190     short_trade_len   1581.0000
# 6       max_drawdown_money  29849.590     longest_win_num      4.0000
# 7             average_rate      0.000    longest_lost_num     11.0000
# 8              stddev_rate      0.050       net_total_pnl  -1113.5146
# 9            positive_year      5.000     net_average_pnl    -11.1351
# 10           negative_year      5.000             win_num     28.0000
# 11           nochange_year      1.000       win_total_pnl  75889.5081
# 12               best_year      9.820     win_average_pnl   2710.3396
# 13              worst_year     -7.470         win_max_pnl  10878.4315
# 14               sqn_ratio     -0.050            lost_num     72.0000
# 15               vwr_ratio     -0.060      lost_total_pnl -77003.0227
# 16             sharpe_info     -0.190    lost_average_pnl  -1069.4864
# 17                   omega      0.000        lost_max_pnl  -3864.6176
#
#                   多空交易指标     多空交易指标值
# 0               long_num      0.0000
# 1           long_win_num      0.0000
# 2          long_lost_num      0.0000
# 3         long_total_pnl      0.0000
# 4       long_average_pnl      0.0000
# 5     long_win_total_pnl      0.0000
# 6       long_win_max_pnl      0.0000
# 7    long_lost_total_pnl      0.0000
# 8      long_lost_max_pnl      0.0000
# 9              short_num    100.0000
# 10         short_win_num     28.0000
# 11        short_lost_num     72.0000
# 12       short_total_pnl  -1113.5146
# 13     short_average_pnl    -11.1351
# 14   short_win_total_pnl  75889.5081
# 15     short_win_max_pnl  10878.4315
# 16  short_lost_total_pnl -77003.0227
# 17    short_lost_max_pnl  -3864.6176

# %%
k2
# Out:
#              total_value
# 2012-01-01  100000.00000
# 2012-01-02  100000.00000
# 2012-01-03  100000.00000
# 2012-01-04  100000.00000
# 2012-01-05  100000.00000
# ...                  ...
# 2019-12-27   91013.22437
# 2019-12-29   90913.22437
# 2019-12-30   90913.10625
# 2019-12-31   90913.10625
# 2020-01-01   90913.10625
#
# [2504 rows x 1 columns]

# %%
k3
# Out:
#             GrossLeverage
# 2012-01-01       0.000000
# 2012-01-02       0.000000
# 2012-01-03       0.000000
# 2012-01-04       0.000000
# 2012-01-05       0.000000
# ...                   ...
# 2019-12-27      -1.227437
# 2019-12-29      -1.229887
# 2019-12-30       0.000000
# 2019-12-31       0.000000
# 2020-01-01       0.000000
#
# [2504 rows x 1 columns]

# %%
k4
# Out:
#             log_return
# 2012-01-01    0.000000
# 2012-01-02    0.000000
# 2012-01-03    0.000000
# 2012-01-04    0.000000
# 2012-01-05    0.000000
# ...                ...
# 2019-12-27   -0.007673
# 2019-12-29   -0.001099
# 2019-12-30   -0.000001
# 2019-12-31    0.000000
# 2020-01-01    0.000000
#
# [2504 rows x 1 columns]

# %%
k5
# Out:
#       year_rate
# 2012  -0.019468
# 2013  -0.032631
# 2014   0.106462
# 2015   0.038086
# 2016  -0.055957
# 2017  -0.056486
# 2018   0.019098
# 2019  -0.080723
# 2020   0.000000

# %%
type(k5)
# Out:
# pandas.core.frame.DataFrame

# %%
k6
# Out:
#                    0  total_position_value
# 2012-01-01       0.0                   0.0
# 2012-01-02       0.0                   0.0
# 2012-01-03       0.0                   0.0
# 2012-01-04       0.0                   0.0
# 2012-01-05       0.0                   0.0
# ...              ...                   ...
# 2019-12-27 -111713.0             -111713.0
# 2019-12-29 -111813.0             -111813.0
# 2019-12-30       0.0                   0.0
# 2019-12-31       0.0                   0.0
# 2020-01-01       0.0                   0.0
#
# [2504 rows x 2 columns]

# %%
k6[k6['total_position_value']<0].describe()
# Out:
#                    0  total_position_value
# count    1276.000000           1276.000000
# mean  -118975.902038        -118975.902038
# std      9708.653586           9708.653586
# min   -138865.000000        -138865.000000
# 25%   -128326.250000        -128326.250000
# 50%   -115767.500000        -115767.500000
# 75%   -111060.750000        -111060.750000
# max   -103906.000000        -103906.000000
