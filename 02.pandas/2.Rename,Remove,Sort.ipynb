# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
orders=pd.read_table('D://data/ufo')
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
orders.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
user_cols=['user_id','age','gender','occupation','zip-code']
users=orders_1=pd.read_table('http://bit.ly/movieusers',sep='|',header=None,names=user_cols)     #打开的是一个table file，数据之间依靠\t进行间隔,header=None表示第一行不是默认的第一行
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.

# %%
orders_1.head(5)
# Out:
#    user_id  age gender  occupation zip-code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
type(orders)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo=pd.read_table('D://data/ufo.csv',sep=',')               #打开的是一个CSVfile，数据之间依靠/进行间隔

# %%
ufo.head(8)
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND  9/15/1934 15:30
# 6           Crater Lake             NaN         CIRCLE    CA   6/15/1935 0:00
# 7                  Alma             NaN           DISK    MI   7/15/1936 0:00

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')
ufo.head(5)
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['City']     #ufo.City也可以
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
ufo.City+'-'+ufo.State         #Series相加
# Out:
# 0                      Ithaca-NY
# 1                 Willingboro-NJ
# 2                     Holyoke-CO
# 3                     Abilene-KS
# 4        New York Worlds Fair-NY
# 5                 Valley City-ND
# 6                 Crater Lake-CA
# 7                        Alma-MI
# 8                     Eklutna-AK
# 9                     Hubbard-OR
# 10                    Fontana-CA
# 11                   Waterloo-AL
# 12                     Belton-SC
# 13                     Keokuk-IA
# 14                  Ludington-MI
# 15                Forest Home-CA
# 16                Los Angeles-CA
# 17                  Hapeville-GA
# 18                     Oneida-TN
# 19                 Bering Sea-AK
# 20                   Nebraska-NE
# 21                           NaN
# 22                           NaN
# 23                  Owensboro-KY
# 24                 Wilderness-WV
# 25                  San Diego-CA
# 26                 Wilderness-WV
# 27                     Clovis-NM
# ...

# %%
ufo['Location']=ufo.City+','+ufo.State

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.shape
# Out:
# (979, 6)

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.describe(include=['object'])
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %% [markdown]
#  <font color=red size=5 face=New Times>Rename</font>

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   Location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
ufo.rename(columns={'Colors Reported':'Colors_Reported','Shape Reported':'Shape_Reported'},inplace=True)   #方法（一）

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
ufo_cols=['City','Color Reported','Shape Reported','State','Time','Location']    #方法（二）
ufo.columns=ufo_cols

# %%
ufo.head()
# Out:
#                    City Color Reported Shape Reported State             Time  \
# 0                Ithaca            NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro            NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke            NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene            NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair            NaN          LIGHT    NY  4/18/1933 19:00
#
#                   Location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo.columns=ufo.columns.str.replace(' ','_')          #方法（三），替代法

# %%
ufo.head()
# Out:
#                    City Color_Reported Shape_Reported State             Time  \
# 0                Ithaca            NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro            NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke            NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene            NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair            NaN          LIGHT    NY  4/18/1933 19:00
#
#                   Location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %% [markdown]
#  <font color=red size=5 face=New Times>Remove</font>

# %%
ufo.drop('Color_Reported',axis=1,inplace=True)   #axis代表方向，0表示行，1表示列, inplace默认为false,那么return就还是原来的结果

# %%
ufo.head()
# Out:
#                    City Shape_Reported State             Time  \
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00
#
#                   Location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo.drop(['City','State'],axis=1,inplace=True)     #同事删掉两行
ufo.head()
# Out:
#   Shape_Reported             Time                 Location
# 0       TRIANGLE   6/1/1930 22:00                Ithaca,NY
# 1          OTHER  6/30/1930 20:00           Willingboro,NJ
# 2           OVAL  2/15/1931 14:00               Holyoke,CO
# 3           DISK   6/1/1931 13:00               Abilene,KS
# 4          LIGHT  4/18/1933 19:00  New York Worlds Fair,NY

# %%
ufo.drop([0,1],axis=0,inplace=True)

# %%
ufo.drop('Location',axis=1,inplace=True)

# %%
ufo.head()
# Out:
#   Shape_Reported             Time
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00
# 5           DISK  9/15/1934 15:30
# 6         CIRCLE   6/15/1935 0:00

# %% [markdown]
#  <font color=red size=5 face=New Times>Sort</font>

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies['title'].sort_values()                 #只针对某个列进行排序，正序
movies['title'].sort_values(ascending=False)  #反序
# Out:
# 864                                  [Rec]
# 526                                   Zulu
# 615                             Zombieland
# 677                                 Zodiac
# 955                       Zero Dark Thirty
# 535                                  Zelig
# 280                     Young Frankenstein
# 96                                 Yojimbo
# 235                                Yip Man
# 403                             Ying xiong
# 695                      Y Tu Mama Tambien
# 871                                     X2
# 532                     X-Men: First Class
# 248             X-Men: Days of Future Past
# 954                                  X-Men
# 518                         Wreck-It Ralph
# 970                            Wonder Boys
# 65             Witness for the Prosecution
# 920                                Witness
# 483                           Withnail & I
# 270                        Wings of Desire
# 497    Willy Wonka & the Chocolate Factory
# ...

# %%
movies.sort_values('title',ascending=False)
# Out:
#      star_rating                                title content_rating  \
# 864          7.5                                [Rec]              R
# 526          7.8                                 Zulu        UNRATED
# 615          7.7                           Zombieland              R
# 677          7.7                               Zodiac              R
# 955          7.4                     Zero Dark Thirty              R
# 535          7.8                                Zelig             PG
# 280          8.1                   Young Frankenstein             PG
# 96           8.4                              Yojimbo        UNRATED
# 235          8.1                              Yip Man              R
# 403          7.9                           Ying xiong          PG-13
# 695          7.7                    Y Tu Mama Tambien              R
# 871          7.5                                   X2          PG-13
# 532          7.8                   X-Men: First Class          PG-13
# ...

# %%
movies.sort_index(ascending=False)      #index排序
# Out:
#      star_rating                                              title  \
# 978          7.4                                        Wall Street
# 977          7.4                                        Poltergeist
# 976          7.4    Master and Commander: The Far Side of the World
# 975          7.4                        Back to the Future Part III
# 974          7.4                                            Tootsie
# 973          7.4                              The Cider House Rules
# 972          7.4                                     Blue Valentine
# 971          7.4                                 Death at a Funeral
# 970          7.4                                        Wonder Boys
# 969          7.4                                Law Abiding Citizen
# 968          7.4                                The English Patient
# 967          7.4                                           The Rock
# 966          7.4                                 The Simpsons Movie
# ...

# %%
movies.shape
# Out:
# (979, 6)
